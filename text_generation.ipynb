# %%
# !pip install transformers

# %%
# !pip install datasets

# %%
from transformers import pipeline, set_seed
from transformers import GPT2Tokenizer, TFGPT2Model
from pprint import pprint
import textwrap
import pandas as pd
import numpy as np

# %%
gen = pipeline('text-generation', model='gpt2-large')

# %%
# kaggle datasets download -d pranithchowdary/python-150k-code
# kaggle datasets download -d kreeshrajani/3k-conversations-dataset-for-chatbot

# %%
gen('The best way to learn python is')
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'The best way to learn python is to make some simple widgets. For example, to create a text widget in one single line:\n\nfrom matplotlib import pyplot as plt with plt.contrib.text.text_types'}]

# %%
# !pip install -q kaggle
# Out:
# ERROR: Operation cancelled by user

# %%
# from google.colab import files
# files.upload()

# %%
# !mkdir ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d pranithchowdary/python-150k-code

# %%
# import zipfile
# zipref = zipfile.ZipFile('/content/python-150k-code.zip')
# zipref.extractall()
# zipref.close()

# %%
# !cat /content/Python_code_data.txt
# Out:
# Streaming output truncated to the last 5000 lines.
#     for col in range(colNum):
#         multilist[row][col]= row*col
#
# print(multilist)
#
# # Write a program that accepts a comma separated sequence of words as input and prints the words in a comma-separated sequence after sorting them alphabetically.
# items=[x for x in input().split(',')]
# items.sort()
# print(','.join(items))
#
# # Write a program that accepts sequence of lines as input and prints the lines after making all characters in the sentence capitalized.
# lines = []
# while True:
#     s = input()
#     if s:
#         lines.append(s.upper())
#     else:
#         break;
#
# for sentence in lines:
#     print(sentence)
#
#
# # Write a program that accepts a sequence of whitespace separated words as input and prints the words after removing all duplicate words and sorting them alphanumerically.
# s = input()
# words = [word for word in s.split(" ")]
# print(" ".join(sorted(list(set(words)))))
#
#
# ...

# %%
lines = [line.rstrip() for line in open("/content/Python_code_data.txt")]
lines = [line for line in lines if len(line)>0]

# %%
lines[0]
# Out:
# '# write a python program to add two numbers'

# %%
gen(lines[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': '# write a python program to add two numbers to a list 1,2\n\nIf we add the numbers 1 and 2 to a list, the value will be returned\n\n[0] = 1\n\n[1] = 2\n\n'}]

# %%
pprint(_)
# Out:
# [{'generated_text': '# write a python program to add two numbers to a list '
#                     '1,2\n'
#                     '\n'
#                     'If we add the numbers 1 and 2 to a list, the value will '
#                     'be returned\n'
#                     '\n'
#                     '[0] = 1\n'
#                     '\n'
#                     '[1] = 2\n'
#                     '\n'}]

# %%
pprint(gen(lines[0], max_length=30))
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': '# write a python program to add two numbers to the '
#                     'database\n'
#                     '\n'
#                     '# the first number will be the value of the second number '
#                     "in the 'table"}]

# %%
pprint(gen(lines[0], max_length=30, num_return_sequences=3))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': '# write a python program to add two numbers 1 and 2\n'
#                     '\n'
#                     'import sys import time # add an int to the left by 2\n'
#                     '\n'
#                     't'},
#  {'generated_text': '# write a python program to add two numbers 1 and 2 to '
#                     'the front of the board\n'
#                     '\n'
#                     'python = "\n'
#                     '\n'
#                     '@(define p ='},
#  {'generated_text': '# write a python program to add two numbers together: - '
#                     'def number_add ( n ): - a = 0 + n - 1 return a def'}]

# %%
def wrap(x):
  return textwrap.fill(x, replace_whitespace=False, fix_sentence_endings=True)

# %%
out = gen(lines[0], max_length=30)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# # write a python program to add two numbers to the deck of cards using
# only 3 pieces of text and a couple lines of code.  You could also

# %%
prev = 'write a python program to add two numbers to the deck of cards using' + \
'only 3 pieces of text and a couple lines of code.'

# %%
out = gen(prev + '\n' + lines[2], max_length=110)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# write a python program to add two numbers to the deck of cards
# usingonly 3 pieces of text and a couple lines of code.
# num1 = 1.5
# num2= 2.4 print num1+num2print "Congratulations"
# num2 = 6.3 print
# num2+num1print "Congratulations"
# It's not the best, but here are the
# cards I used:-
# The "p" cards are the "spades", the "a" cards are the
# "hundred-card" deck.
# The

# %%
prev = 'write a python program to add two numbers to the deck of cards using' + \
'only 3 pieces of text and a couple lines of code.\n' + \
'num1 = 1.5 num2= 2.4 ' + \
'print num1+num2' + \
'print "Congratulations"'

# %%
out = gen(prev + '\n' + lines[3], max_length=110)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# write a python program to add two numbers to the deck of cards
# usingonly 3 pieces of text and a couple lines of code.
# num1 = 1.5
# num2= 2.4 print num1+num2print "Congratulations"
# sum = num1 + num2
# #print sum#
# I've written several other python programs to help me test
# out this post but I'll leave it to you to make those a bit better.
# As
# an aside, I would really like to do some testing with the following
# cards in the deck

# %%
lines
# Out:
# ['# write a python program to add two numbers',
#  'num1 = 1.5',
#  'num2 = 6.3',
#  'sum = num1 + num2',
#  "print(f'Sum: {sum}')",
#  '# write a python function to add two user provided numbers and return the sum',
#  'def add_two_numbers(num1, num2):',
#  '    sum = num1 + num2',
#  '    return sum',
#  '# write a program to find and print the largest among three numbers',
#  'num1 = 10',
#  'num2 = 12',
#  'num3 = 14',
#  'if (num1 >= num2) and (num1 >= num3):',
#  '   largest = num1',
#  'elif (num2 >= num1) and (num2 >= num3):',
#  '   largest = num2',
#  'else:',
#  '   largest = num3',
#  "print(f'largest:{largest}')",
#  '# write a program to find and print the smallest among three numbers',
#  'num1 = 10',
#  'num2 = 12',
#  'num3 = 14',
#  'if (num1 <= num2) and (num1 <= num3):',
#  '   smallest = num1',
#  'elif (num2 <= num1) and (num2 <= num3):',
#  '   smallest = num2',
#  'else:',
#  '   smallest = num3',
#  "print(f'smallest:{smallest}')",
# ...

# %%
import time

# %%
prompt = 'write a python program that prints out natural numbers less than or equal to the given number using a while loop'

out = gen(prompt, max_length=300)
for i in wrap(out[0]['generated_text']):
  print(i, end='')
  time.sleep(0.5)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# write a python program that prints out natural numbers less than or
# equal to the given number using a while loop, using a list of numbers.
# This tutorial will teach you how to write a python program that prints
# out natural numbers less than or equal to the given number using a
# while loop, using a list of numbers.
#
# This tutorial will teach you how
# to compile a python program into a standalone executable.  To do so,
# we will use cpython and mp
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-296c653084e7> in <cell line: 4>()
#       4 for i in wrap(out[0]['generated_text']):
#       5   print(i, end='')
# ----> 6   time.sleep(0.5)
#
# KeyboardInterrupt:

# %%
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 24.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 12.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.7/310.7 kB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 50.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 8.7 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline
import gradio as gr

# Load a pre-trained chatbot model
chatbot = pipeline("conversational")

def wrap(x):
  return textwrap.fill(x, replace_whitespace=False, fix_sentence_endings=True)

def chat(prompt):
  out = chatbot(prompt)
  for i in wrap(out[0]['generated_text']):
    print(i, end='')
    time.sleep(0.2)

gr.Interface(fn=chat, inputs="text", outputs="text").launch()
# Out:
# No model was supplied, defaulted to microsoft/DialoGPT-medium and revision 8bada3b (https://huggingface.co/microsoft/DialoGPT-medium).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://1d0ac11973f39be5ac.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://1d0ac11973f39be5ac.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
chatbot = pipeline("conversational")
# Out:
# No model was supplied, defaulted to microsoft/DialoGPT-medium and revision 8bada3b (https://huggingface.co/microsoft/DialoGPT-medium).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
prompt = 'the best whay to learn python'
gen(prompt)[0]['generated_text']
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# "the best whay to learn python\n\nI like to learn python, most of my code is python\n\nI love using my laptop to do things, if you have a mac, you should definitely try it\n\nYou probably don't know"
